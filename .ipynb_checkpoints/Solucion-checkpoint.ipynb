# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ###Presentación de la Solución
#
# Responda las siguientes preguntas (en un cuaderno de ipython, documento de `.Rmd`, o `shinyapp` ):
#
# 1. Qué otros datos pueden ayudarlo a mejorar su predicción?
# 2. Cuál día de la semana presenta el número mayor de órdenes?
# 3. Cuál día de la semana presenta el menor número de órdenes?
#
# Su solución debe llevarse a cabo en el repositorio `HW8_NombreApellido` y debe incluir:
# - El código que detalla su modelo predictivo.
# - Cualquier intuición y/o visualizaciones que usted obtenga a partir de esos datos.
# - Las respuestas a las preguntas planteadas.

# %% [markdown]
# ###Observar los datos

# %%
# !ls
# !wc test_set.csv
# !wc training_set.csv
# Out:
# Ejemplos  README.md		 Solucion.ipynb  training_set.csv
# hw8.pdf   sample_submission.csv  test_set.csv	 wc
#   47   47 1904 test_set.csv
#  138  138 6059 training_set.csv

# %%
data = pd.read_csv('training_set.csv')
data.head()
# Out:
#         fecha  cod_calendario  conteo_ordenes  conteo_restaurantes  temp_max  \
# 0  2012-09-01               0             165                    6      30.6
# 1  2012-09-02               1             138                    8      32.8
# 2  2012-09-03               1             127                    9      29.4
# 3  2012-09-04               1             174                   10      29.4
# 4  2012-09-05               1             196                   11      30.6
#
#    temp_min  precipitacion          eventos
# 0      22.8            0.0           Lluvia
# 1      22.8           15.5  Lluvia-Tormenta
# 2      18.3            0.0          Ninguno
# 3      17.2            0.0          Ninguno
# 4      21.7            0.0           Niebla

# %%
print(data.shape)
# Out:
# (137, 8)

# %%
fig, axs = subplots(1, 3, sharey=True)
data.plot(kind='scatter', x='cod_calendario', y='conteo_ordenes', ax=axs[0], figsize=(12, 6))
data.plot(kind='scatter', x='conteo_restaurantes', y='conteo_ordenes',ax=axs[1])
data.plot(kind='scatter', x='precipitacion', y='conteo_ordenes', ax=axs[2])

# %% [markdown]
# A partir de las gráficas se puede inferir que existe una correlacion fuerte entre el _cod_calendario_ y la salida. Tambien existe relacion fuerte entre el _conteo_restaurantes_ y la salida

# %%
fig, axs = subplots(1, 2, sharey=True)
data.plot(kind='scatter', x='temp_max', y='conteo_ordenes', ax=axs[0], figsize=(12, 6))
data.plot(kind='scatter', x='temp_min', y='conteo_ordenes', ax=axs[1])

# %%
import statsmodels.formula.api as smf

# %%
lm = smf.ols(formula='conteo_ordenes ~ conteo_restaurantes + cod_calendario*temp_max', data=data).fit()

# %%
lm.params
# Out:
# Intercept                  -34.094936
# conteo_restaurantes         17.929322
# cod_calendario             112.079752
# temp_max                    -0.894795
# cod_calendario:temp_max     -2.196439
# dtype: float64

# %%
X_new = data[['conteo_restaurantes','cod_calendario','temp_max']]
preds = lm.predict(X_new)

# %%
print(shape(preds))
# Out:
# (137,)

# %%
plot(data.conteo_restaurantes,data.conteo_ordenes,'bo')
plot(X_new.conteo_restaurantes,preds,'r.');grid()

# %% [markdown]
# ###Test

# %%
# !ls
# Out:
# Ejemplos  README.md		 Solucion.ipynb  training_set.csv
# hw8.pdf   sample_submission.csv  test_set.csv

# %%
test_data = pd.read_csv('test_set.csv')
test_data.head()
# Out:
#         fecha  cod_calendario  conteo_restaurantes  temp_max  temp_min  \
# 0  2012-10-01               1                   10      24.4      15.0
# 1  2012-10-02               1                   11      21.1      12.8
# 2  2012-10-03               1                   12      22.2      12.2
# 3  2012-10-04               1                   12      21.7       7.2
# 4  2012-10-05               1                   14      16.7       3.9
#
#    precipitacion  eventos
# 0            0.0  Ninguno
# 1            0.0  Ninguno
# 2            2.8   Lluvia
# 3           10.7   Lluvia
# 4            0.0  Ninguno

# %%
test_data.shape
# Out:
# (46, 7)

# %%
X_test = test_data[['conteo_restaurantes','cod_calendario','temp_max']]
preds = lm.predict(X_test)

# %%
#plot(test_data.conteo_restaurantes,test_data.conteo_ordenes,'bo')
plot(X_test.conteo_restaurantes,preds,'r.');grid()

# %%
lm.rsquared
# Out:
# 0.71903776708249867

# %% [markdown]
# ###Escribir resultados

# %%
# !ls
# !head sample_submission.csv
# Out:
# Ejemplos  README.md		 Solucion.ipynb  training_set.csv
# hw8.pdf   sample_submission.csv  test_set.csv	 wc
# "fecha","conteo_ordenes"
# "2012-10-01",500
# "2012-10-02",400
# "2012-10-03",300
# "2012-10-04",100

# %%
fechas = array(test_data.fecha)

# %%
prediccion = open('prediccion.csv','w')
encabezado = '"fecha","conteo_ordenes"\n'
prediccion.writelines(encabezado)

#Escribir los datos
for i in range(len(preds)):
    #print('"%s",%d'%(fechas[i],preds[i]))
    prediccion.writelines('"%s",%d\n'%(fechas[i],preds[i]))
prediccion.close()

# %%
# !head prediccion.csv
# !wc prediccion.csv
# Out:
# "fecha","conteo_ordenes"
# "2012-10-01",181
# "2012-10-02",209
# "2012-10-03",224
# "2012-10-04",226
# "2012-10-05",277
# "2012-10-06",168
# "2012-10-07",190
# "2012-10-08",201
# "2012-10-09",209
#  47  47 807 prediccion.csv
